# %% [markdown]
# INSTALANDO BIBLIOTECAS

# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy
# !pip install scikit-learn

# %% [markdown]
# IMPORTANDO

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sk

# %% [markdown]
# LENDO A BASE DADOS
#
# Pd = Pandas |
# Df = dataframe |
# pd.read_csv = Pandas lê arquivo CSV

# %%
df = pd.read_csv("cogumelos_MODIFICADO.csv")

# %%
df.info()

# %% [markdown]
# COLUNAS COM DADOS FALTANTES

# %%
df = df.drop(columns=["coluna completamente inutil (me remova)"])

# %%
df = df.drop(columns=["coluna de origem duvidosa (use por sua conta em risco)"])

# %%
df.info()

# %%
df_limpo = df.dropna(axis=0) #limpando linhas

# %%
df_limpo.info()

# %% [markdown]
# ANALISANDO DADOS
#
# Objetivo é escolher as melhores colunas para treinar a máquina. Acredito que o heatmap irá nos ajudar a identificar isso.
#
# Colunas destaques: Diametro do caule, altura do caule, largura do caule, cor do caule.

# %%
sns.heatmap(df_limpo.corr(), vmin=-1, vmax=+1, annot=True, cmap="coolwarm")
# Out:
# <Axes: >
